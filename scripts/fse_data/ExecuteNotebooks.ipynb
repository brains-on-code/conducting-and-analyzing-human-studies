# %%
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# note: seems not to work when data.head(5) is called somewhere; probably has issues when a notebook
# displays data in a table (it also creates a table to display the data)
# , encoding="utf-8" is necessary to avoid encoding error

path = '/users/author1/ml_exec/FSE_full/'

# === Data Preprocessing ============================================================
with open('DataPreprocessing.ipynb') as f:
    caps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(caps, {'metadata': {'path': path}})
with open('executed_DataPreprocessing.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(caps, f)
print('Finished Notebook: DataPreprocessing')
# === Data Preprocessing ============================================================


# === Coarse Average =============================================================
with open('PredictionOfTrialCoarseAverageParticipantSplit_Act.ipynb') as f:
    caps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(caps, {'metadata': {'path': path}})
with open('executed_CoarseAverageParticipantSplit_act.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(caps, f)
print('Finished Notebook: PredictionOfTrialCoarseAverageParticipantSplit_Act')

with open('PredictionOfTrialCoarseAverageParticipantSplit_AllROIS.ipynb') as f:
    cars = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(cars, {'metadata': {'path': path}})
with open('executed_CoarseAverageParticipantSplit_allROIS.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(cars, f)
print('Finished Notebook: PredictionOfTrialCoarseAverageParticipantSplit_AllROIS')

with open('PredictionOfTrialCoarseAverageParticipantSplit_Deact.ipynb') as f:
    cars = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(cars, {'metadata': {'path': path}})
with open('executed_CoarseAverageParticipantSplit_deact.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(cars, f)
print('Finished Notebook: PredictionOfTrialCoarseAverageParticipantSplit_Deact')
# === Coarse Average =============================================================

# === Fine Average =============================================================
with open('PredictionOfTrialFineAverageParticipantSplit_Act.ipynb') as f:
    fars = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fars, {'metadata': {'path': path}})
with open('executed_FineAverageParticipantSplit_Act.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fars, f)
print('Finished Notebook: PredictionOfTrialFineAverageParticipantSplit_Act')
    
with open('PredictionOfTrialFineAverageParticipantSplit_AllROIS.ipynb') as f:
    fats = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fats, {'metadata': {'path': path}})
with open('executed_FineAverageParticipantSplit_AllROIS.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fats, f)
print('Finished Notebook: PredictionOfTrialFineAverageParticipantSplit_AllROIS')

with open('PredictionOfTrialFineAverageParticipantSplit_Deact.ipynb') as f:
    faps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(faps, {'metadata': {'path': path}})
with open('executed_FineAverageParticipantSplit_Deact.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(faps, f)
print('Finished Notebook: PredictionOfTrialFineAverageParticipantSplit_Deact')
# === Fine Average =============================================================

# === Not Aggregated =============================================================
with open('PredictionOfTrialNotAggregatedParticipantSplit_Act.ipynb') as f:
    fars = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fars, {'metadata': {'path': path}})
with open('executed_PredictionOfTrialNotAggregatedParticipantSplit_Act.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fars, f)
print('Finished Notebook: PredictionOfTrialNotAggregatedParticipantSplit_Act')
    
with open('PredictionOfTrialNotAggregatedParticipantSplit_AllROIs.ipynb') as f:
    fats = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fats, {'metadata': {'path': path}})
with open('executed_PredictionOfTrialNotAggregatedParticipantSplit_AllROIs.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fats, f)
print('Finished Notebook: PredictionOfTrialNotAggregatedParticipantSplit_AllROIs')

with open('PredictionOfTrialNotAggregatedParticipantSplit_Deact.ipynb') as f:
    faps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(faps, {'metadata': {'path': path}})
with open('executed_PredictionOfTrialNotAggregatedParticipantSplit_Deact.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(faps, f)
print('Finished Notebook: PredictionOfTrialNotAggregatedParticipantSplit_Deact')
# === Not Aggregated =============================================================

#=== Triangulation =============================================================
with open('PredictionTriangulateAggregationLevelParticipantSplit_Act.ipynb') as f:
    fars = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fars, {'metadata': {'path': path}})
with open('PredictionTriangulateAggregationLevelParticipantSplit_Act.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fars, f)
print('Finished Notebook: PredictionTriangulateAggregationLevelParticipantSplit_Act')
    
with open('PredictionTriangulateAggregationLevelParticipantSplit_AllROIs.ipynb') as f:
    fats = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(fats, {'metadata': {'path': path}})
with open('PredictionTriangulateAggregationLevelParticipantSplit_AllROIs.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(fats, f)
print('Finished Notebook: PredictionTriangulateAggregationLevelParticipantSplit_AllROIs')

with open('PredictionTriangulateAggregationLevelParticipantSplit_Deact.ipynb') as f:
    faps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(faps, {'metadata': {'path': path}})
with open('PredictionTriangulateAggregationLevelParticipantSplit_Deact.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(faps, f)
print('Finished Notebook: PredictionTriangulateAggregationLevelParticipantSplit_Deact')
# === Triangulation =============================================================

#=== Plot Data =====================================================================
with open('PlotData.ipynb') as f:
    caps = nbformat.read(f, as_version=4)
ep = ExecutePreprocessor(timeout=-1, interrupt_on_timeout=False)
ep.preprocess(caps, {'metadata': {'path': path}})
with open('executed_PlotData.ipynb', 'wt', encoding="utf-8") as f:
    nbformat.write(caps, f)
print('Finished Notebook: PlotData')
# === Plot Data ============================================================
